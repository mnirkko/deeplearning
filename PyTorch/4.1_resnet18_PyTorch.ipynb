# %% [markdown]
# <a href="http://cocl.us/pytorch_link_top">
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0110EN/notebook_images%20/Pytochtop.png" width="750" alt="IBM Product ">
# </a>

# %% [markdown]
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DL0321EN-SkillsNetwork/image/IDSN-logo.png" width="200" alt="cognitiveclass.ai logo">

# %% [markdown]
# <h1><h1>Pre-trained-Models with PyTorch </h1>

# %% [markdown]
# In this lab, you will use pre-trained models to classify between the negative and positive samples; you will be provided with the dataset object. The particular pre-trained model will be resnet18; you will have three questions:
# <ul>
# <li>change the output layer</li>
# <li> train the model</li>
# <li>  identify  several  misclassified samples</li>
#  </ul>
# You will take several screenshots of your work and share your notebook.

# %% [markdown]
# <h2>Table of Contents</h2>

# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
#
# <ul>
#     <li><a href="#download_data"> Download Data</a></li>
#     <li><a href="#auxiliary"> Imports and Auxiliary Functions </a></li>
#     <li><a href="#data_class"> Dataset Class</a></li>
#     <li><a href="#Question_1">Question 1</a></li>
#     <li><a href="#Question_2">Question 2</a></li>
#     <li><a href="#Question_3">Question 3</a></li>
# </ul>
# <p>Estimated Time Needed: <strong>120 min</strong></p>
#  </div>
# <hr>

# %% [markdown]
# <h2 id="download_data">Download Data</h2>

# %% [markdown]
# Download the dataset and unzip the files in your data directory, unlike the other labs, all the data will be deleted after you close  the lab, this may take some time:

# %%
# !wget https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/images/Positive_tensors.zip 
# !unzip -q Positive_tensors.zip
# !wget https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/images/Negative_tensors.zip
# !unzip -q Negative_tensors.zip

# %% [markdown]
# We will install torchvision:

# %%
# !pip install torchvision

# %% [markdown]
# <h2 id="auxiliary">Imports and Auxiliary Functions</h2>

# %% [markdown]
# The following are the libraries we are going to use for this lab. The <code>torch.manual_seed()</code> is for forcing the random function to give the same number every time we try to recompile it.

# %%
# These are the libraries will be used for this lab.
import torchvision.models as models
from PIL import Image
import pandas
from torchvision import transforms
import torch.nn as nn
import time
import torch 
import matplotlib.pylab as plt
import numpy as np
from torch.utils.data import Dataset, DataLoader
import h5py
import os
import glob
torch.manual_seed(0)

# %%
from matplotlib.pyplot import imshow
import matplotlib.pylab as plt
from PIL import Image
import pandas as pd
import os

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="data_class">Dataset Class</h2>

# %% [markdown]
#  This dataset class is essentially the same dataset you build in the previous section, but to speed things up, we are going to use tensors instead of jpeg images. Therefor for each iteration, you will skip the reshape step, conversion step to tensors and normalization step.

# %%
# Create your own dataset object
class Dataset(Dataset):

    # Constructor
    def __init__(self,transform=None,train=True):
        directory=os.path.expanduser('~')
        positive="Positive_tensors"
        negative='Negative_tensors'

        positive_file_path=os.path.join(directory,positive)
        negative_file_path=os.path.join(directory,negative)
        positive_files=[os.path.join(positive_file_path,file) for file in os.listdir(positive_file_path) if file.endswith(".pt")]
        negative_files=[os.path.join(negative_file_path,file) for file in os.listdir(negative_file_path) if file.endswith(".pt")]
        number_of_samples=len(positive_files)+len(negative_files)
        self.all_files=[None]*number_of_samples
        self.all_files[::2]=positive_files
        self.all_files[1::2]=negative_files 
        # The transform is goint to be used on image
        self.transform = transform
        #torch.LongTensor
        self.Y=torch.zeros([number_of_samples]).type(torch.LongTensor)
        self.Y[::2]=1
        self.Y[1::2]=0
        
        if train:
            self.all_files=self.all_files[0:30000]
            self.Y=self.Y[0:30000]
            self.len=len(self.all_files)
        else:
            self.all_files=self.all_files[30000:]
            self.Y=self.Y[30000:]
            self.len=len(self.all_files)     
       
    # Get the length
    def __len__(self):
        return self.len
    
    # Getter
    def __getitem__(self, idx):
               
        image=torch.load(self.all_files[idx])
        y=self.Y[idx]
                  
        # If there is any transform method, apply it onto the image
        if self.transform:
            image = self.transform(image)

        return image, y
    
print("done")
# Out:
# done

# %% [markdown]
# We create two dataset objects, one for the training data and one for the validation data.

# %%
train_dataset = Dataset(train=True)
validation_dataset = Dataset(train=False)
print("done")
# Out:
# done

# %% [markdown]
# <h2 id="Question_1">Question 1</h2>

# %% [markdown]
# <b>Prepare a pre-trained resnet18 model :</b>

# %% [markdown]
# <b>Step 1</b>: Load the pre-trained model <code>resnet18</code> Set the parameter <code>pretrained</code> to true:

# %%
# Step 1: Load the pre-trained model resnet18

# Type your code here
model = models.resnet18(pretrained=True)

# %% [markdown]
# <b>Step 2</b>: Set the attribute <code>requires_grad</code> to <code>False</code>. As a result, the parameters will not be affected by training.

# %%
# Step 2: Set the parameter cannot be trained for the pre-trained model


# Type your code here
model.requires_grad_(False)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )

# %% [markdown]
# <code>resnet18</code> is used to classify 1000 different objects; as a result, the last layer has 1000 outputs.  The 512 inputs come from the fact that the previously hidden layer has 512 outputs.

# %% [markdown]
# <b>Step 3</b>: Replace the output layer <code>model.fc</code> of the neural network with a <code>nn.Linear</code> object, to classify 2 different classes. For the parameters <code>in_features </code> remember the last hidden layer has 512 neurons.

# %%
model.fc = nn.Linear(512, 2)

# %% [markdown]
# Print out the model in order to show whether you get the correct answer.<br> <b>(Your peer reviewer is going to mark based on what you print here.)</b>

# %%
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=2, bias=True)
# )

# %% [markdown]
# <h2 id="Question_2">Question 2: Train the Model</h2>

# %% [markdown]
# In this question you will train your, model:

# %% [markdown]
# <b>Step 1</b>: Create a cross entropy criterion function

# %%
# Step 1: Create the loss function

# Type your code here
criterion = nn.CrossEntropyLoss()

# %% [markdown]
# <b>Step 2</b>: Create a training loader and validation loader object, the batch size should have 100 samples each.

# %%
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=100)
validation_loader = torch.utils.data.DataLoader(dataset=validation_dataset, batch_size=100)

# %% [markdown]
# <b>Step 3</b>: Use the following optimizer to minimize the loss

# %%
optimizer = torch.optim.Adam([parameters  for parameters in model.parameters() if parameters.requires_grad],lr=0.001)

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# **Complete the following code to calculate  the accuracy on the validation data for one epoch; this should take about 45 minutes. Make sure you calculate the accuracy on the validation data.**

# %%
n_epochs=1
loss_list=[]
accuracy_list=[]
correct=0
N_test=len(validation_dataset)
N_train=len(train_dataset)
start_time = time.time()

Loss=0
start_time = time.time()
for epoch in range(n_epochs):
    count_train = 0
    for x, y in train_loader:
        count_train += 1
        print(f"Training model... ({count_train} / {len(train_loader)})")
        # set model to train
        model.train() 
        # clear gradient
        optimizer.zero_grad()
        # make a prediction
        z = model(x)
        # calculate loss
        loss = criterion(z, y)
        # calculate gradients of parameters
        loss.backward()
        # update parameters
        optimizer.step()
        loss_list.append(loss.data)
    correct=0
    count_val = 0
    for x_test, y_test in validation_loader:
        count_val += 1
        print(f"Validating model... ({count_val} / {len(validation_loader)})")
        # set model to eval 
        model.eval()
        # make a prediction
        z = model(x_test)
        # find max
        _, yhat = torch.max(z.data, 1)
        # Calculate misclassified samples in mini-batch
        correct += (yhat == y_test).sum().item()   
    accuracy=correct/N_test
# Out:
# Training model... (1 / 30000)
# Training model... (2 / 30000)
# Training model... (3 / 30000)
# Training model... (4 / 30000)
# Training model... (5 / 30000)
# Training model... (6 / 30000)
# Training model... (7 / 30000)
# Training model... (8 / 30000)
# Training model... (9 / 30000)
# Training model... (10 / 30000)
# Training model... (11 / 30000)
# Training model... (12 / 30000)
# Training model... (13 / 30000)
# Training model... (14 / 30000)
# Training model... (15 / 30000)
# Training model... (16 / 30000)
# Training model... (17 / 30000)
# Training model... (18 / 30000)
# Training model... (19 / 30000)
# Training model... (20 / 30000)
# Training model... (21 / 30000)
# Training model... (22 / 30000)
# Training model... (23 / 30000)
# Training model... (24 / 30000)
# Training model... (25 / 30000)
# Training model... (26 / 30000)
# Training model... (27 / 30000)
# Training model... (28 / 30000)
# Training model... (29 / 30000)
# Training model... (30 / 30000)
# Training model... (31 / 30000)
# Training model... (32 / 30000)
# Training model... (33 / 30000)
# Training model... (34 / 30000)
# Training model... (35 / 30000)
# Training model... (36 / 30000)
# Training model... (37 / 30000)
# Training model... (38 / 30000)
# Training model... (39 / 30000)
# Training model... (40 / 30000)
# Training model... (41 / 30000)
# Training model... (42 / 30000)
# Training model... (43 / 30000)
# Training model... (44 / 30000)
# Training model... (45 / 30000)
# Training model... (46 / 30000)
# Training model... (47 / 30000)
# Training model... (48 / 30000)
# Training model... (49 / 30000)
# Training model... (50 / 30000)
# Training model... (51 / 30000)
# Training model... (52 / 30000)
# Training model... (53 / 30000)
# Training model... (54 / 30000)
# Training model... (55 / 30000)
# Training model... (56 / 30000)
# Training model... (57 / 30000)
# Training model... (58 / 30000)
# Training model... (59 / 30000)
# Training model... (60 / 30000)
# Training model... (61 / 30000)
# Training model... (62 / 30000)
# Training model... (63 / 30000)
# Training model... (64 / 30000)
# Training model... (65 / 30000)
# Training model... (66 / 30000)
# Training model... (67 / 30000)
# Training model... (68 / 30000)
# Training model... (69 / 30000)
# Training model... (70 / 30000)
# Training model... (71 / 30000)
# Training model... (72 / 30000)
# Training model... (73 / 30000)
# Training model... (74 / 30000)
# Training model... (75 / 30000)
# Training model... (76 / 30000)
# Training model... (77 / 30000)
# Training model... (78 / 30000)
# Training model... (79 / 30000)
# Training model... (80 / 30000)
# Training model... (81 / 30000)
# Training model... (82 / 30000)
# Training model... (83 / 30000)
# Training model... (84 / 30000)
# Training model... (85 / 30000)
# Training model... (86 / 30000)
# Training model... (87 / 30000)
# Training model... (88 / 30000)
# Training model... (89 / 30000)
# Training model... (90 / 30000)
# Training model... (91 / 30000)
# Training model... (92 / 30000)
# Training model... (93 / 30000)
# Training model... (94 / 30000)
# Training model... (95 / 30000)
# Training model... (96 / 30000)
# Training model... (97 / 30000)
# Training model... (98 / 30000)
# Training model... (99 / 30000)
# Training model... (100 / 30000)
# Training model... (101 / 30000)
# Training model... (102 / 30000)
# Training model... (103 / 30000)
# Training model... (104 / 30000)
# Training model... (105 / 30000)
# Training model... (106 / 30000)
# Training model... (107 / 30000)
# Training model... (108 / 30000)
# Training model... (109 / 30000)
# Training model... (110 / 30000)
# Training model... (111 / 30000)
# Training model... (112 / 30000)
# Training model... (113 / 30000)
# Training model... (114 / 30000)
# Training model... (115 / 30000)
# Training model... (116 / 30000)
# Training model... (117 / 30000)
# Training model... (118 / 30000)
# Training model... (119 / 30000)
# Training model... (120 / 30000)
# Training model... (121 / 30000)
# Training model... (122 / 30000)
# Training model... (123 / 30000)
# Training model... (124 / 30000)
# Training model... (125 / 30000)
# Training model... (126 / 30000)
# Training model... (127 / 30000)
# Training model... (128 / 30000)
# Training model... (129 / 30000)
# Training model... (130 / 30000)
# Training model... (131 / 30000)
# Training model... (132 / 30000)
# Training model... (133 / 30000)
# Training model... (134 / 30000)
# Training model... (135 / 30000)
# Training model... (136 / 30000)
# Training model... (137 / 30000)
# Training model... (138 / 30000)
# Training model... (139 / 30000)
# Training model... (140 / 30000)
# Training model... (141 / 30000)
# Training model... (142 / 30000)
# Training model... (143 / 30000)
# Training model... (144 / 30000)
# Training model... (145 / 30000)
# Training model... (146 / 30000)
# Training model... (147 / 30000)
# Training model... (148 / 30000)
# Training model... (149 / 30000)
# Training model... (150 / 30000)
# Training model... (151 / 30000)
# Training model... (152 / 30000)
# Training model... (153 / 30000)
# Training model... (154 / 30000)
# Training model... (155 / 30000)
# Training model... (156 / 30000)
# Training model... (157 / 30000)
# Training model... (158 / 30000)
# Training model... (159 / 30000)
# Training model... (160 / 30000)
# Training model... (161 / 30000)
# Training model... (162 / 30000)
# Training model... (163 / 30000)
# Training model... (164 / 30000)
# Training model... (165 / 30000)
# Training model... (166 / 30000)
# Training model... (167 / 30000)
# Training model... (168 / 30000)
# Training model... (169 / 30000)
# Training model... (170 / 30000)
# Training model... (171 / 30000)
# Training model... (172 / 30000)
# Training model... (173 / 30000)
# Training model... (174 / 30000)
# Training model... (175 / 30000)
# Training model... (176 / 30000)
# Training model... (177 / 30000)
# Training model... (178 / 30000)
# Training model... (179 / 30000)
# Training model... (180 / 30000)
# Training model... (181 / 30000)
# Training model... (182 / 30000)
# Training model... (183 / 30000)
# Training model... (184 / 30000)
# Training model... (185 / 30000)
# Training model... (186 / 30000)
# Training model... (187 / 30000)
# Training model... (188 / 30000)
# Training model... (189 / 30000)
# Training model... (190 / 30000)
# Training model... (191 / 30000)
# Training model... (192 / 30000)
# Training model... (193 / 30000)
# Training model... (194 / 30000)
# Training model... (195 / 30000)
# Training model... (196 / 30000)
# Training model... (197 / 30000)
# Training model... (198 / 30000)
# Training model... (199 / 30000)
# Training model... (200 / 30000)
# Training model... (201 / 30000)
# Training model... (202 / 30000)
# Training model... (203 / 30000)
# Training model... (204 / 30000)
# Training model... (205 / 30000)
# Training model... (206 / 30000)
# Training model... (207 / 30000)
# Training model... (208 / 30000)
# Training model... (209 / 30000)
# Training model... (210 / 30000)
# Training model... (211 / 30000)
# Training model... (212 / 30000)
# Training model... (213 / 30000)
# Training model... (214 / 30000)
# Training model... (215 / 30000)
# Training model... (216 / 30000)
# Training model... (217 / 30000)
# Training model... (218 / 30000)
# Training model... (219 / 30000)
# Training model... (220 / 30000)
# Training model... (221 / 30000)
# Training model... (222 / 30000)
# Training model... (223 / 30000)
# Training model... (224 / 30000)
# Training model... (225 / 30000)
# Training model... (226 / 30000)
# Training model... (227 / 30000)
# Training model... (228 / 30000)
# Training model... (229 / 30000)
# Training model... (230 / 30000)
# Training model... (231 / 30000)
# Training model... (232 / 30000)
# Training model... (233 / 30000)
# Training model... (234 / 30000)
# Training model... (235 / 30000)
# Training model... (236 / 30000)
# Training model... (237 / 30000)
# Training model... (238 / 30000)
# Training model... (239 / 30000)
# Training model... (240 / 30000)
# Training model... (241 / 30000)
# Training model... (242 / 30000)
# Training model... (243 / 30000)
# Training model... (244 / 30000)
# Training model... (245 / 30000)
# Training model... (246 / 30000)
# Training model... (247 / 30000)
# Training model... (248 / 30000)
# Training model... (249 / 30000)
# Training model... (250 / 30000)
# Training model... (251 / 30000)
# Training model... (252 / 30000)
# Training model... (253 / 30000)
# Training model... (254 / 30000)
# Training model... (255 / 30000)
# Training model... (256 / 30000)
# Training model... (257 / 30000)
# Training model... (258 / 30000)
# Training model... (259 / 30000)
# Training model... (260 / 30000)
# Training model... (261 / 30000)
# Training model... (262 / 30000)
# Training model... (263 / 30000)
# Training model... (264 / 30000)
# Training model... (265 / 30000)
# Training model... (266 / 30000)
# Training model... (267 / 30000)
# Training model... (268 / 30000)
# Training model... (269 / 30000)
# Training model... (270 / 30000)
# Training model... (271 / 30000)
# Training model... (272 / 30000)
# Training model... (273 / 30000)
# Training model... (274 / 30000)
# Training model... (275 / 30000)
# Training model... (276 / 30000)
# Training model... (277 / 30000)
# Training model... (278 / 30000)
# Training model... (279 / 30000)
# Training model... (280 / 30000)
# Training model... (281 / 30000)
# Training model... (282 / 30000)
# Training model... (283 / 30000)
# Training model... (284 / 30000)
# Training model... (285 / 30000)
# Training model... (286 / 30000)
# Training model... (287 / 30000)
# Training model... (288 / 30000)
# Training model... (289 / 30000)
# Training model... (290 / 30000)
# Training model... (291 / 30000)
# Training model... (292 / 30000)
# Training model... (293 / 30000)
# Training model... (294 / 30000)
# Training model... (295 / 30000)
# Training model... (296 / 30000)
# Training model... (297 / 30000)
# Training model... (298 / 30000)
# Training model... (299 / 30000)
# Training model... (300 / 30000)
# Validating model... (1 / 10000)
# Validating model... (2 / 10000)
# Validating model... (3 / 10000)
# Validating model... (4 / 10000)
# Validating model... (5 / 10000)
# Validating model... (6 / 10000)
# Validating model... (7 / 10000)
# Validating model... (8 / 10000)
# Validating model... (9 / 10000)
# Validating model... (10 / 10000)
# Validating model... (11 / 10000)
# Validating model... (12 / 10000)
# Validating model... (13 / 10000)
# Validating model... (14 / 10000)
# Validating model... (15 / 10000)
# Validating model... (16 / 10000)
# Validating model... (17 / 10000)
# Validating model... (18 / 10000)
# Validating model... (19 / 10000)
# Validating model... (20 / 10000)
# Validating model... (21 / 10000)
# Validating model... (22 / 10000)
# Validating model... (23 / 10000)
# Validating model... (24 / 10000)
# Validating model... (25 / 10000)
# Validating model... (26 / 10000)
# Validating model... (27 / 10000)
# Validating model... (28 / 10000)
# Validating model... (29 / 10000)
# Validating model... (30 / 10000)
# Validating model... (31 / 10000)
# Validating model... (32 / 10000)
# Validating model... (33 / 10000)
# Validating model... (34 / 10000)
# Validating model... (35 / 10000)
# Validating model... (36 / 10000)
# Validating model... (37 / 10000)
# Validating model... (38 / 10000)
# Validating model... (39 / 10000)
# Validating model... (40 / 10000)
# Validating model... (41 / 10000)
# Validating model... (42 / 10000)
# Validating model... (43 / 10000)
# Validating model... (44 / 10000)
# Validating model... (45 / 10000)
# Validating model... (46 / 10000)
# Validating model... (47 / 10000)
# Validating model... (48 / 10000)
# Validating model... (49 / 10000)
# Validating model... (50 / 10000)
# Validating model... (51 / 10000)
# Validating model... (52 / 10000)
# Validating model... (53 / 10000)
# Validating model... (54 / 10000)
# Validating model... (55 / 10000)
# Validating model... (56 / 10000)
# Validating model... (57 / 10000)
# Validating model... (58 / 10000)
# Validating model... (59 / 10000)
# Validating model... (60 / 10000)
# Validating model... (61 / 10000)
# Validating model... (62 / 10000)
# Validating model... (63 / 10000)
# Validating model... (64 / 10000)
# Validating model... (65 / 10000)
# Validating model... (66 / 10000)
# Validating model... (67 / 10000)
# Validating model... (68 / 10000)
# Validating model... (69 / 10000)
# Validating model... (70 / 10000)
# Validating model... (71 / 10000)
# Validating model... (72 / 10000)
# Validating model... (73 / 10000)
# Validating model... (74 / 10000)
# Validating model... (75 / 10000)
# Validating model... (76 / 10000)
# Validating model... (77 / 10000)
# Validating model... (78 / 10000)
# Validating model... (79 / 10000)
# Validating model... (80 / 10000)
# Validating model... (81 / 10000)
# Validating model... (82 / 10000)
# Validating model... (83 / 10000)
# Validating model... (84 / 10000)
# Validating model... (85 / 10000)
# Validating model... (86 / 10000)
# Validating model... (87 / 10000)
# Validating model... (88 / 10000)
# Validating model... (89 / 10000)
# Validating model... (90 / 10000)
# Validating model... (91 / 10000)
# Validating model... (92 / 10000)
# Validating model... (93 / 10000)
# Validating model... (94 / 10000)
# Validating model... (95 / 10000)
# Validating model... (96 / 10000)
# Validating model... (97 / 10000)
# Validating model... (98 / 10000)
# Validating model... (99 / 10000)
# Validating model... (100 / 10000)

# %% [markdown]
# <b>Print out the Accuracy and plot the loss stored in the list <code>loss_list</code> for every iteration and take a screen shot.</b>

# %%
accuracy
# Out:
# 0.9943

# %%
plt.plot(loss_list)
plt.xlabel("iteration")
plt.ylabel("loss")
plt.show()

# %% [markdown]
# <h2 id="Question_3">Question 3:Find the misclassified samples</h2>

# %% [markdown]
# <b>Identify the first four misclassified samples using the validation data:</b>

# %%
validation_loader = torch.utils.data.DataLoader(dataset=validation_dataset, batch_size=1)
misclassified = 0
count = 0
for x, y in validation_loader:
    z = model(x)
    _, yhat = torch.max(z, 1)
    count += 1
    if yhat==y: continue
    misclassified += 1
    print(f"Misclassified sample #{count-1}: predicted {yhat}, actual {y}")
    if misclassified>=4: break
# Out:
# Misclassified sample #22: predicted tensor([0]), actual tensor([1])
# Misclassified sample #101: predicted tensor([1]), actual tensor([0])
# Misclassified sample #182: predicted tensor([0]), actual tensor([1])
# Misclassified sample #213: predicted tensor([1]), actual tensor([0])

# %% [markdown]
# <a href="https://dataplatform.cloud.ibm.com/docs/content/wsj/analyze-data/share-notebooks.html?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDL0321ENSkillsNetwork951-2022-01-01"> CLICK HERE </a> Click here to see how to share your notebook.

# %% [markdown]
# <h2>About the Authors:</h2>
#
# <a href="https://www.linkedin.com/in/joseph-s-50398b136/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDL0321ENSkillsNetwork951-2022-01-01">Joseph Santarcangelo</a> has a PhD in Electrical Engineering, his research focused on using machine learning, signal processing, and computer vision to determine how videos impact human cognition. Joseph has been working for IBM since he completed his PhD.

# %% [markdown]
# ## Change Log
#
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2020-09-21  | 2.0  | Shubham  |  Migrated Lab to Markdown and added to course repo in GitLab |
#
#
#
# <hr>
#
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>

# %% [markdown]
# Copyright &copy; 2018 <a href="cognitiveclass.ai?utm_source=bducopyrightlink&utm_medium=dswb&utm_campaign=bdu">cognitiveclass.ai</a>. This notebook and its source code are released under the terms of the <a href="https://bigdatauniversity.com/mit-license/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDL0321ENSkillsNetwork951-2022-01-01">MIT License</a>.
